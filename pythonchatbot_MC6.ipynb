# %% [markdown]
# <a href="https://colab.research.google.com/github/AyaAls777/AiResidency/blob/main/pythonchatbot_MC6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gradio

# %%
from openai import OpenAI
from google.colab import userdata
import gradio as gr

# Retrieve API key
api_key = userdata.get('openai')

# Create OpenAI client
client = OpenAI(api_key=api_key)

# Tutor bot function
def tutor_bot(user_input):

    # Exit condition
    if user_input.lower() == "exit":
        return "👋 Thanks for learning with me! Happy coding! 🚀"

    # Send request to OpenAI
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a beginner-friendly Python tutor bot. "
                    "Explain concepts simply, provide examples, "
                    "help debug code, and encourage learning."
                )
            },
            {
                "role": "user",
                "content": user_input
            }
        ],
        temperature=0.3,
        max_tokens=500
    )

    # Return AI response
    return response.choices[0].message.content


# Gradio interface
demo = gr.Interface(
    fn=tutor_bot,
    inputs=gr.Textbox(
        lines=2,
        placeholder="Ask a Python question..."
    ),
    outputs="text",
    title="💡 Python Tutor Bot",
    description="Ask me any Python-related question."
)

# Launch app
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://661ddf9a6afe59972e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://661ddf9a6afe59972e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
